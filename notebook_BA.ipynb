# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, HiveContext

# %%
# !pip install PySPARQL==0.0.5
# Out:
# Requirement already satisfied: PySPARQL==0.0.5 in /opt/conda/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: graphframes in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (0.6)
# Requirement already satisfied: sparqlwrapper in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (1.8.5)
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (5.0.0)
# Requirement already satisfied: rdflib-jsonld in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (0.5.0)
# Requirement already satisfied: pyspark in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (3.0.1)
# Requirement already satisfied: nose in /opt/conda/lib/python3.8/site-packages (from graphframes->PySPARQL==0.0.5) (1.3.7)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from graphframes->PySPARQL==0.0.5) (1.19.4)
# Requirement already satisfied: py4j==0.10.9 in /opt/conda/lib/python3.8/site-packages (from pyspark->PySPARQL==0.0.5) (0.10.9)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.8/site-packages (from rdflib->PySPARQL==0.0.5) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from rdflib->PySPARQL==0.0.5) (1.15.0)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.8/site-packages (from rdflib->PySPARQL==0.0.5) (0.6.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from rdflib->PySPARQL==0.0.5) (1.15.0)
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (5.0.0)
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.8/site-packages (from PySPARQL==0.0.5) (5.0.0)

# %%
from PySPARQL.Wrapper import PySPARQLWrapper

# %% [markdown]
# ### Connection to Apache Spark

# %%
spark = (SparkSession
          .builder
          .appName("interfacing spark sql to hive metastore without configuration file")
          .config("hive.metastore.uris", "thrift://hive-metastore:9083") 
          .enableHiveSupport() 
          .getOrCreate())

# %% [markdown]
# ### SPARQL query execution

# %%
sparql_endpoint = "http://jena-fuseki:3030/pizzads"

query = """
    PREFIX : <http://www.co-ode.org/ontologies/pizza/pizza.owl#>

    SELECT (COUNT(?anomalous)/(COUNT(?pizzaChecked)) as ?count) ?restaurant
    WHERE {
    SERVICE <http://ontop:8080/sparql> {
        {?anomalous a :AnomalousPizza; :restaurant ?restaurant.}
        UNION
        {?pizzaChecked a :QAPizza; :restaurant ?restaurant.}
       }
    }
    GROUP BY ?restaurant
"""

wrapper = PySPARQLWrapper(spark, sparql_endpoint)
result = wrapper.query(query)
resultDF = result.dataFrame
# Out:
# count,restaurant
# 0.666666666666666666666666,RESTAURANT_1
# 0.222222222222222222222222,RESTAURANT_2
# 0.4,RESTAURANT_3

# %%
resultDF.show()
# Out:
# +--------------------+------------+
# |               count|  restaurant|
# +--------------------+------------+
# |0.666666666666666...|RESTAURANT_1|
# |0.222222222222222...|RESTAURANT_2|
# |                 0.4|RESTAURANT_3|
# +--------------------+------------+

# %% [markdown]
# ### Plot the results using Pandas

# %%
import pandas as pd

pandasDF = resultDF.toPandas()

# %%
df = pd.DataFrame({'RESTAURANTS':pandasDF["restaurant"], '% ANOMALIES':pandasDF["count"].astype(float)})
ax = df.plot.barh(x='RESTAURANTS', y='% ANOMALIES', stacked=False,figsize=(7,2))
ax.set_ylabel("")
ax.set_xlim(0,1)
# Out:
# (0.0, 1.0)
